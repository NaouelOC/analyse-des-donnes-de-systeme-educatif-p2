# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import missingno as msno

# %% [markdown]
# ## 1. import and read dataset
# ## 2. Dataset EdStatsData

# %%
df= pd.read_csv("EdStatsData.csv",sep = ',')
pd.set_option('display.max_columns', None)

# %%
df.head()
# Out:
#   Country Name Country Code  \
# 0   Arab World          ARB
# 1   Arab World          ARB
# 2   Arab World          ARB
# 3   Arab World          ARB
# 4   Arab World          ARB
#
#                                       Indicator Name  Indicator Code  \
# 0  Adjusted net enrolment rate, lower secondary, ...      UIS.NERA.2
# 1  Adjusted net enrolment rate, lower secondary, ...    UIS.NERA.2.F
# 2  Adjusted net enrolment rate, lower secondary, ...  UIS.NERA.2.GPI
# 3  Adjusted net enrolment rate, lower secondary, ...    UIS.NERA.2.M
# 4  Adjusted net enrolment rate, primary, both sex...     SE.PRM.TENR
#
#         1970       1971       1972       1973       1974      1975       1976  \
# 0        NaN        NaN        NaN        NaN        NaN       NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN       NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN       NaN        NaN
# ...

# %%
df.shape
# Out:
# (886930, 70)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 886930 entries, 0 to 886929
# Data columns (total 70 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Country Name    886930 non-null  object
#  1   Country Code    886930 non-null  object
#  2   Indicator Name  886930 non-null  object
#  3   Indicator Code  886930 non-null  object
#  4   1970            72288 non-null   float64
#  5   1971            35537 non-null   float64
#  6   1972            35619 non-null   float64
#  7   1973            35545 non-null   float64
#  8   1974            35730 non-null   float64
#  9   1975            87306 non-null   float64
#  10  1976            37483 non-null   float64
#  11  1977            37574 non-null   float64
#  12  1978            37576 non-null   float64
#  13  1979            36809 non-null   float64
#  14  1980            89122 non-null   float64
#  15  1981            38777 non-null   float64
# ...

# %% [markdown]
# ### visualize the null value for all the dataset

# %%
msno.bar(df,color="dodgerblue", fontsize=14)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### keep data between 2000 and 2015

# %%
df_new = df[df.columns[df.columns.isin(["Country Name","Country Code","Indicator Name","Indicator Code","2000","2001","2002","2003","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015"])]]

# %%
df_new.shape
# Out:
# (886930, 19)

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 886930 entries, 0 to 886929
# Data columns (total 19 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Country Name    886930 non-null  object
#  1   Country Code    886930 non-null  object
#  2   Indicator Name  886930 non-null  object
#  3   Indicator Code  886930 non-null  object
#  4   2000            176676 non-null  float64
#  5   2001            123509 non-null  float64
#  6   2002            124205 non-null  float64
#  7   2003            130363 non-null  float64
#  8   2005            184108 non-null  float64
#  9   2006            140312 non-null  float64
#  10  2007            137272 non-null  float64
#  11  2008            134387 non-null  float64
#  12  2009            142108 non-null  float64
#  13  2010            242442 non-null  float64
#  14  2011            146012 non-null  float64
#  15  2012            147264 non-null  float64
# ...

# %% [markdown]
# ### check country with less data during this period

# %%
list_country = df_new["Country Name"].value_counts().index.tolist()

# %%
len(list_country)
# Out:
# 242

# %%
null_percentage = df_new.isnull().sum()/df_new.shape[0]*100  # percentage of null in every column

# %%
null_percentage
# Out:
# Country Name       0.000000
# Country Code       0.000000
# Indicator Name     0.000000
# Indicator Code     0.000000
# 2000              80.080051
# 2001              86.074549
# 2002              85.996076
# 2003              85.301771
# 2005              79.242105
# 2006              84.180037
# 2007              84.522792
# 2008              84.848071
# 2009              83.977541
# 2010              72.665036
# 2011              83.537370
# 2012              83.396209
# 2013              84.496071
# 2014              87.170464
# 2015              85.223411
# dtype: float64

# %%
df_new.isnull().sum(axis = 1)
# Out:
# 0         15
# 1         15
# 2         15
# 3         15
# 4          1
#           ..
# 886925    13
# 886926    13
# 886927    13
# 886928    13
# 886929    13
# Length: 886930, dtype: int64

# %%
msno.bar(df_new, fontsize=14)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## create dataframe with the good indicator

# %% [raw]
# df_new["Indicator Name"].value_counts().index.tolist()

# %%
df_new["Country Name"].value_counts().index.tolist()
# Out:
# ['Arab World',
#  'Portugal',
#  'Micronesia, Fed. Sts.',
#  'Moldova',
#  'Monaco',
#  'Mongolia',
#  'Montenegro',
#  'Morocco',
#  'Mozambique',
#  'Myanmar',
#  'Namibia',
#  'Nauru',
#  'Nepal',
#  'Netherlands',
#  'New Caledonia',
#  'New Zealand',
#  'Nicaragua',
#  'Niger',
#  'Nigeria',
#  'Northern Mariana Islands',
#  'Norway',
#  'Oman',
#  'Pakistan',
#  'Palau',
#  'Panama',
#  'Papua New Guinea',
#  'Paraguay',
#  'Peru',
#  'Philippines',
#  'Mexico',
#  'Mauritius',
#  'Mauritania',
#  'Lesotho',
#  'Jordan',
#  'Kazakhstan',
#  'Kenya',
#  'Kiribati',
#  'Korea, Dem. People’s Rep.',
#  'Korea, Rep.',
#  'Kosovo',
#  'Kuwait',
#  'Kyrgyz Republic',
#  'Lao PDR',
#  'Latvia',
#  'Lebanon',
#  'Liberia',
#  'Marshall Islands',
#  'Libya',
#  'Liechtenstein',
#  'Lithuania',
#  'Luxembourg',
#  'Macao SAR, China',
#  'Macedonia, FYR',
#  'Madagascar',
#  'Malawi',
#  'Malaysia',
#  'Maldives',
#  'Mali',
#  'Malta',
#  'Poland',
#  'Puerto Rico',
# ...

# %%
df_new.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '2000', '2001', '2002', '2003', '2005', '2006', '2007', '2008', '2009',
#        '2010', '2011', '2012', '2013', '2014', '2015'],
#       dtype='object')

# %%
indicator_list = ["Barro-Lee: Percentage of population age 15+ with secondary schooling. Completed Secondary",
                  "Enrolment in secondary education","Enrolment in tertiary education",
                  "Percentage of enrolment in tertiary education in private institutions (%)",
                 "Percentage of enrolment in secondary education in private institutions (%)","Percentage of enrolment in upper secondary education in private institutions (%)",
                 "GDP at market prices (current US$)","GDP per capita","Internet users (per 100 people)","Personal computers (per 100 people)"]

# %%
df_indicator = df_new[df_new['Indicator Name'].isin(indicator_list)]## select list of indicator

# %%
df_indicator.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1694 entries, 377 to 885349
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    1694 non-null   object
#  1   Country Code    1694 non-null   object
#  2   Indicator Name  1694 non-null   object
#  3   Indicator Code  1694 non-null   object
#  4   2000            1043 non-null   float64
#  5   2001            926 non-null    float64
#  6   2002            970 non-null    float64
#  7   2003            952 non-null    float64
#  8   2005            1115 non-null   float64
#  9   2006            902 non-null    float64
#  10  2007            852 non-null    float64
#  11  2008            842 non-null    float64
#  12  2009            826 non-null    float64
#  13  2010            989 non-null    float64
#  14  2011            862 non-null    float64
#  15  2012            847 non-null    float64
# ...

# %%
df_indicator = df_indicator.reindex()

# %%
df_indicator.shape
# Out:
# (1694, 19)

# %%
df_indicator.head()
# Out:
#      Country Name Country Code  \
# 377    Arab World          ARB
# 1243   Arab World          ARB
# 1375   Arab World          ARB
# 1856   Arab World          ARB
# 1857   Arab World          ARB
#
#                                          Indicator Name        Indicator Code  \
# 377   Barro-Lee: Percentage of population age 15+ wi...  BAR.SEC.CMPT.15UP.ZS
# 1243                 GDP at market prices (current US$)        NY.GDP.MKTP.CD
# 1375                    Internet users (per 100 people)        IT.NET.USER.P2
# 1856  Percentage of enrolment in secondary education...        SE.SEC.PRIV.ZS
# 1857  Percentage of enrolment in tertiary education ...        SE.TER.PRIV.ZS
#
#               2000          2001          2002          2003          2005  \
# 377            NaN           NaN           NaN           NaN           NaN
# 1243  7.260126e+11  7.130072e+11  7.240099e+11  8.155385e+11  1.176100e+12
# 1375  1.139541e+00  1.561288e+00  2.693061e+00  3.645881e+00  8.393142e+00
# ...

# %% [markdown]
# ### check null values

# %%
msno.bar(df_indicator,color="dodgerblue", fontsize=14)
# Out:
# <AxesSubplot:>

# %%
df_indicator[df_indicator.isnull().any(1)]##find row contain nan
# Out:
#        Country Name Country Code  \
# 377      Arab World          ARB
# 1243     Arab World          ARB
# 1375     Arab World          ARB
# 1856     Arab World          ARB
# 1857     Arab World          ARB
# ...             ...          ...
# 883642     Zimbabwe          ZWE
# 885121     Zimbabwe          ZWE
# 885122     Zimbabwe          ZWE
# 885123     Zimbabwe          ZWE
# 885349     Zimbabwe          ZWE
#
#                                            Indicator Name  \
# 377     Barro-Lee: Percentage of population age 15+ wi...
# 1243                   GDP at market prices (current US$)
# 1375                      Internet users (per 100 people)
# 1856    Percentage of enrolment in secondary education...
# 1857    Percentage of enrolment in tertiary education ...
# ...                                                   ...
# 883642  Barro-Lee: Percentage of population age 15+ wi...
# 885121  Percentage of enrolment in secondary education...
# ...

# %%
result = df_indicator.isnull().sum(axis = 1) ## find sum nan value

# %%
print(result)
# Out:
# 377       15
# 1243       2
# 1375       2
# 1856       1
# 1857      15
#           ..
# 884640     0
# 885121    12
# 885122    12
# 885123    13
# 885349     8
# Length: 1694, dtype: int64

# %%
 ## condition with row with most nan value here 13 as condition
country_nan_value = df_indicator[df_indicator.isnull().sum(axis = 1)>12]

# %%
country_nan_value.head()
# Out:
#              Country Name Country Code  \
# 377            Arab World          ARB
# 1857           Arab World          ARB
# 1858           Arab World          ARB
# 4042  East Asia & Pacific          EAS
# 5522  East Asia & Pacific          EAS
#
#                                          Indicator Name        Indicator Code  \
# 377   Barro-Lee: Percentage of population age 15+ wi...  BAR.SEC.CMPT.15UP.ZS
# 1857  Percentage of enrolment in tertiary education ...        SE.TER.PRIV.ZS
# 1858  Percentage of enrolment in upper secondary edu...             UIS.PRP.3
# 4042  Barro-Lee: Percentage of population age 15+ wi...  BAR.SEC.CMPT.15UP.ZS
# 5522  Percentage of enrolment in tertiary education ...        SE.TER.PRIV.ZS
#
#       2000  2001  2002  2003  2005  2006  2007  2008  2009  2010  2011  2012  \
# 377    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1857   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...

# %%
col_list = country_nan_value["Country Name"].values.tolist()# transform column to list

# %%
col_list
# Out:
# ['Arab World',
#  'Arab World',
#  'Arab World',
#  'East Asia & Pacific',
#  'East Asia & Pacific',
#  'East Asia & Pacific',
#  'East Asia & Pacific (excluding high income)',
#  'East Asia & Pacific (excluding high income)',
#  'East Asia & Pacific (excluding high income)',
#  'Euro area',
#  'Euro area',
#  'Euro area',
#  'Europe & Central Asia',
#  'Europe & Central Asia',
#  'Europe & Central Asia',
#  'Europe & Central Asia (excluding high income)',
#  'Europe & Central Asia (excluding high income)',
#  'Europe & Central Asia (excluding high income)',
#  'European Union',
#  'European Union',
#  'European Union',
#  'Heavily indebted poor countries (HIPC)',
#  'Heavily indebted poor countries (HIPC)',
#  'Heavily indebted poor countries (HIPC)',
#  'High income',
#  'High income',
#  'High income',
#  'Latin America & Caribbean',
#  'Latin America & Caribbean',
#  'Latin America & Caribbean',
#  'Latin America & Caribbean (excluding high income)',
# ...

# %% [markdown]
# ### drop those countries

# %%
## drop countries in the  list containig too much nan values
df_indicator_droped = df_indicator[df_indicator["Country Name"].isin(col_list) == False]

# %%
df_indicator_droped["Country Name"]
# Out:
# 95667         Albania
# 96533         Albania
# 96665         Albania
# 97146         Albania
# 97147         Albania
#              ...
# 877310    Yemen, Rep.
# 877791    Yemen, Rep.
# 877792    Yemen, Rep.
# 877793    Yemen, Rep.
# 878019    Yemen, Rep.
# Name: Country Name, Length: 693, dtype: object

# %%
 df_indicator_droped.isnull().sum(axis = 1)
# Out:
# 95667     12
# 96533      0
# 96665      0
# 97146      6
# 97147      3
#           ..
# 877310     0
# 877791     9
# 877792    12
# 877793     9
# 878019     9
# Length: 693, dtype: int64

# %%
df_indicator_droped.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 693 entries, 95667 to 878019
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    693 non-null    object
#  1   Country Code    693 non-null    object
#  2   Indicator Name  693 non-null    object
#  3   Indicator Code  693 non-null    object
#  4   2000            566 non-null    float64
#  5   2001            485 non-null    float64
#  6   2002            505 non-null    float64
#  7   2003            493 non-null    float64
#  8   2005            610 non-null    float64
#  9   2006            477 non-null    float64
#  10  2007            452 non-null    float64
#  11  2008            450 non-null    float64
#  12  2009            434 non-null    float64
#  13  2010            532 non-null    float64
#  14  2011            445 non-null    float64
#  15  2012            436 non-null    float64
# ...

# %% [markdown]
# ### list of countries we will study

# %%
df_indicator_droped['Country Name'].count() ##
# Out:
# 693

# %%
df_indicator_droped['Country Name']
# Out:
# 95667         Albania
# 96533         Albania
# 96665         Albania
# 97146         Albania
# 97147         Albania
#              ...
# 877310    Yemen, Rep.
# 877791    Yemen, Rep.
# 877792    Yemen, Rep.
# 877793    Yemen, Rep.
# 878019    Yemen, Rep.
# Name: Country Name, Length: 693, dtype: object

# %%
df_indicator_droped.head()
# Out:
#       Country Name Country Code  \
# 95667      Albania          ALB
# 96533      Albania          ALB
# 96665      Albania          ALB
# 97146      Albania          ALB
# 97147      Albania          ALB
#
#                                           Indicator Name  \
# 95667  Barro-Lee: Percentage of population age 15+ wi...
# 96533                 GDP at market prices (current US$)
# 96665                    Internet users (per 100 people)
# 97146  Percentage of enrolment in secondary education...
# 97147  Percentage of enrolment in tertiary education ...
#
#              Indicator Code          2000          2001          2002  \
# 95667  BAR.SEC.CMPT.15UP.ZS  2.663000e+01           NaN           NaN
# 96533        NY.GDP.MKTP.CD  3.632044e+09  4.060759e+09  4.435079e+09
# 96665        IT.NET.USER.P2  1.140973e-01  3.257984e-01  3.900813e-01
# 97146        SE.SEC.PRIV.ZS           NaN           NaN           NaN
# ...

# %%
df_indicator_droped.reset_index(drop = True, inplace = True)
df_indicator_droped.head()
# Out:
#   Country Name Country Code  \
# 0      Albania          ALB
# 1      Albania          ALB
# 2      Albania          ALB
# 3      Albania          ALB
# 4      Albania          ALB
#
#                                       Indicator Name        Indicator Code  \
# 0  Barro-Lee: Percentage of population age 15+ wi...  BAR.SEC.CMPT.15UP.ZS
# 1                 GDP at market prices (current US$)        NY.GDP.MKTP.CD
# 2                    Internet users (per 100 people)        IT.NET.USER.P2
# 3  Percentage of enrolment in secondary education...        SE.SEC.PRIV.ZS
# 4  Percentage of enrolment in tertiary education ...        SE.TER.PRIV.ZS
#
#            2000          2001          2002          2003          2005  \
# 0  2.663000e+01           NaN           NaN           NaN  3.292000e+01
# 1  3.632044e+09  4.060759e+09  4.435079e+09  5.746946e+09  8.158549e+09
# 2  1.140973e-01  3.257984e-01  3.900813e-01  9.719004e-01  6.043891e+00
# ...

# %%
df_indicator_droped.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '2000', '2001', '2002', '2003', '2005', '2006', '2007', '2008', '2009',
#        '2010', '2011', '2012', '2013', '2014', '2015'],
#       dtype='object')

# %% [markdown]
# ## merge with EdStats Country to get other informations

# %%
df_edstats_country = pd.read_csv("EdStatsCountry.csv", sep = ',')
pd.set_option('display.max_columns', None)
df_edstats_country.head(3)
# Out:
#   Country Code   Short Name   Table Name                     Long Name  \
# 0          ABW        Aruba        Aruba                         Aruba
# 1          AFG  Afghanistan  Afghanistan  Islamic State of Afghanistan
# 2          AGO       Angola       Angola   People's Republic of Angola
#
#   2-alpha code   Currency Unit  \
# 0           AW   Aruban florin
# 1           AF  Afghan afghani
# 2           AO  Angolan kwanza
#
#                                        Special Notes  \
# 0  SNA data for 2000-2011 are updated from offici...
# 1  Fiscal year end: March 20; reporting period fo...
# 2  April 2013 database update: Based on IMF data,...
#
#                       Region          Income Group WB-2 code  \
# 0  Latin America & Caribbean  High income: nonOECD        AW
# 1                 South Asia            Low income        AF
# 2         Sub-Saharan Africa   Upper middle income        AO
#
#   National accounts base year  National accounts reference year  \
# ...

# %%
data = pd.merge(df_indicator_droped,df_edstats_country[["Country Code","Region","Income Group","Latest population census"]])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 693 entries, 0 to 692
# Data columns (total 22 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Country Name              693 non-null    object
#  1   Country Code              693 non-null    object
#  2   Indicator Name            693 non-null    object
#  3   Indicator Code            693 non-null    object
#  4   2000                      566 non-null    float64
#  5   2001                      485 non-null    float64
#  6   2002                      505 non-null    float64
#  7   2003                      493 non-null    float64
#  8   2005                      610 non-null    float64
#  9   2006                      477 non-null    float64
#  10  2007                      452 non-null    float64
#  11  2008                      450 non-null    float64
#  12  2009                      434 non-null    float64
# ...

# %%
data.head(3)
# Out:
#   Country Name Country Code  \
# 0      Albania          ALB
# 1      Albania          ALB
# 2      Albania          ALB
#
#                                       Indicator Name        Indicator Code  \
# 0  Barro-Lee: Percentage of population age 15+ wi...  BAR.SEC.CMPT.15UP.ZS
# 1                 GDP at market prices (current US$)        NY.GDP.MKTP.CD
# 2                    Internet users (per 100 people)        IT.NET.USER.P2
#
#            2000          2001          2002          2003          2005  \
# 0  2.663000e+01           NaN           NaN           NaN  3.292000e+01
# 1  3.632044e+09  4.060759e+09  4.435079e+09  5.746946e+09  8.158549e+09
# 2  1.140973e-01  3.257984e-01  3.900813e-01  9.719004e-01  6.043891e+00
#
#            2006          2007          2008          2009          2010  \
# 0           NaN           NaN           NaN           NaN  4.290000e+01
# 1  8.992642e+09  1.070101e+10  1.288135e+10  1.204421e+10  1.192695e+10
# ...

# %% [markdown]
# ### check the region of countries we kept

# %%
list_region_country = data["Region"].value_counts()

# %%
list_region_country
# Out:
# Europe & Central Asia         252
# Latin America & Caribbean     126
# East Asia & Pacific           112
# Sub-Saharan Africa             98
# Middle East & North Africa     63
# South Asia                     35
# North America                   7
# Name: Region, dtype: int64

# %% [markdown]
# ## check the income group and OECD

# %%
data["Income Group"].value_counts()
# Out:
# Upper middle income     203
# High income: OECD       196
# Lower middle income     161
# High income: nonOECD     77
# Low income               56
# Name: Income Group, dtype: int64

# %% [raw]
# we have more data available concerning the countries belonging to the OECD

# %% [raw]
# We have more values for country in rich region

# %% [markdown]
# ## first pivot method

# %%
df_pivot = df_indicator_droped.pivot_table(index=['Country Name'], columns=['Indicator Name'],values=['2000', '2001', '2002', '2003', '2005', '2006', 
                                 '2007', '2008', '2009','2010','2011','2012','2013','2014','2015'])

# %%
df_pivot.head()
# Out:
#                                                                                                     2000  \
# Indicator Name Barro-Lee: Percentage of population age 15+ with secondary schooling. Completed Secondary
# Country Name
# Albania                                                     26.63
# Algeria                                                     15.41
# Argentina                                                   24.53
# Armenia                                                     61.77
# Australia                                                   57.04
#
#                                                    \
# Indicator Name GDP at market prices (current US$)
# Country Name
# Albania                              3.632044e+09
# Algeria                              5.479025e+10
# Argentina                            2.842038e+11
# Armenia                              1.911564e+09
# Australia                            4.154462e+11
#
# ...

# %%
df_pivot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 99 entries, Albania to Yemen, Rep.
# Data columns (total 87 columns):
#  #   Column                                                                                             Non-Null Count  Dtype
# ---  ------                                                                                             --------------  -----
#  0   (2000, Barro-Lee: Percentage of population age 15+ with secondary schooling. Completed Secondary)  99 non-null     float64
#  1   (2000, GDP at market prices (current US$))                                                         99 non-null     float64
#  2   (2000, Internet users (per 100 people))                                                            97 non-null     float64
#  3   (2000, Percentage of enrolment in secondary education in private institutions (%))                 65 non-null     float64
# ...

# %% [markdown]
# ### second pivot method

# %% [raw]
# df_melt = pd.melt(df_indicator_droped, id_vars=["Country Name","Indicator Code","Indicator Name",],
#      value_vars=['2000', '2001', '2002', '2003', '2005', '2006',
#                                  '2007', '2008', '2009','2010','2011','2012','2013','2014','2015']
#     ,var_name= "years" ,value_name=["Indicator Value"])
# df_melt["Indicator Value"] = round(df_melt["indicator Value"],2)
# df_melt['Qcut']=pd.qcut(df_melt["Indicator Value"],2,labels=['1','2'])

# %%
df_pivot_two = df_indicator_droped.pivot_table(index=['Country Name'], columns=['Indicator Code'],values=['2000', '2001', '2002', '2003', '2005', '2006', 
                                 '2007', '2008', '2009','2010','2011','2012','2013','2014','2015'])

# %%
df_pivot_two.head()
# Out:
#                                2000                                \
# Indicator Code BAR.SEC.CMPT.15UP.ZS IT.CMP.PCMP.P2 IT.NET.USER.P2
# Country Name
# Albania                       26.63       0.756442       0.114097
# Algeria                       15.41       0.630528       0.491706
# Argentina                     24.53       6.937093       7.038683
# Armenia                       61.77       0.812718       1.300470
# Australia                     57.04      46.730484      46.756116
#
#                                                                         \
# Indicator Code NY.GDP.MKTP.CD SE.SEC.PRIV.ZS SE.TER.PRIV.ZS  UIS.PRP.3
# Country Name
# Albania          3.632044e+09            NaN            NaN   1.881920
# Algeria          5.479025e+10            NaN            NaN        NaN
# Argentina        2.842038e+11      25.093981            NaN  29.816441
# Armenia          1.911564e+09            NaN            NaN        NaN
# ...

# %%
df_pivot_two.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 99 entries, Albania to Yemen, Rep.
# Data columns (total 87 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   (2000, BAR.SEC.CMPT.15UP.ZS)  99 non-null     float64
#  1   (2000, IT.CMP.PCMP.P2)        95 non-null     float64
#  2   (2000, IT.NET.USER.P2)        97 non-null     float64
#  3   (2000, NY.GDP.MKTP.CD)        99 non-null     float64
#  4   (2000, SE.SEC.PRIV.ZS)        65 non-null     float64
#  5   (2000, SE.TER.PRIV.ZS)        48 non-null     float64
#  6   (2000, UIS.PRP.3)             63 non-null     float64
#  7   (2001, IT.CMP.PCMP.P2)        98 non-null     float64
#  8   (2001, IT.NET.USER.P2)        97 non-null     float64
#  9   (2001, NY.GDP.MKTP.CD)        99 non-null     float64
#  10  (2001, SE.SEC.PRIV.ZS)        70 non-null     float64
#  11  (2001, SE.TER.PRIV.ZS)        51 non-null     float64
# ...

# %% [markdown]
# ### class indicator per year

# %%
class_indicator = df_pivot_two.notna().sum()/len(df_pivot_two)*100

# %%
class_indicator_sorted = class_indicator.sort_values(ascending= False)

# %%
class_indicator_sorted
# Out:
#       Indicator Code
# 2000  BAR.SEC.CMPT.15UP.ZS    100.000000
# 2002  NY.GDP.MKTP.CD          100.000000
# 2009  IT.NET.USER.P2          100.000000
# 2010  BAR.SEC.CMPT.15UP.ZS    100.000000
# 2007  NY.GDP.MKTP.CD          100.000000
#                                  ...
# 2000  SE.TER.PRIV.ZS           48.484848
# 2007  IT.CMP.PCMP.P2           29.292929
# 2008  IT.CMP.PCMP.P2           18.181818
# 2009  IT.CMP.PCMP.P2            2.020202
# 2015  UIS.PRP.3                 1.010101
# Length: 87, dtype: float64
